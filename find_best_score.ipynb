# %%
import pandas as pd

# %%
data_path = "data/eg_peaks_anno.csv"

# %%
df = pd.read_csv(data_path)

# %%
best_df = df.loc[df.groupby(["Gene Name"])["Peak Score"].idxmax()]

# %%
best_df.head()
# Out:
#        Unnamed: 0  \
# 7263        11070
# 14522       42314
# 8965        15664
# 8420        14035
# 7239        11020
#
#       PeakID (cmd=annotatePeaks.pl 2019-11-05-TCE_ATAC-C0024-AHKNL2BGXC/homer/BATC0000063_homer_filtered.peak hg38-bowtie2/genome.fa -gtf hg38-bowtie2/genes.gtf -annStats 2019-11-05-TCE_ATAC-C0024-AHKNL2BGXC/homer/BATC0000063_homer_filtered.peak.annostats)  \
# 7263                                             1-11080
# 14522                                            1-42274
# 8965                                             1-15658
# 8420                                             1-13991
# 7239                                             1-11021
#
#          Chr      Start        End Strand  Peak Score  \
# 7263    chr9  114957817  114958782      +       27.00
# 14522   chr4  164383379  164383671      +        5.28
# 8965   chr16   30382210   30383043      +       18.50
# 8420    chr2  109613859  109614468      +       20.80
# ...
